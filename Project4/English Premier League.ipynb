# %% [markdown]
# **This data science project aims to analyze a dataset related to the most successful seasons of prominent football teams to uncover patterns and derive insights. The main objectives include calculating statistical measures such as identifying the most successful seasons for various teams, finding the team with the most accurate shots on target, and analyzing penalty success rates. Additionally, the project involves visualizing data distributions using bar charts and pie charts to better understand team performances and success rates.**
#
# 1.	importing our library.
# 2.	reading our dataset
# 3.	find the rows count
# 4.	find the most successful season of Manchester United and keep it
# 5.	find the most successful season of Manchester City and keep it
# 6.	find the most successful season of Liverpool and keep it
# 7.	find the most successful season of Chelsea and keep it
# 8.	find the most successful season of Arsenal and keep it
# 9.	find the most successful season of Tottenham and keep it
# 10.	create a new dataframe and add these teams
# 11.	find the most successful team in the new dataframe
# 12.	find the team that lost the most in the new dataframe
# 13.	find the team with the most accurate shots on target in 2016.
# 14.	At new dataframe: Add a new column named “Penalty success rate”, and this column calculates and shows us the team’s penalty success rate.
# 15.	Find the most successful team on penalty saving at new data frame.
# 16.	At new dataframe: Create a bar chart that showed the distribution of teams by points.
# 17.	At new dataframe: Create a pie chart that showed the distribution of teams by goal attempts.

# %% [markdown]
# ## 1.importing our library

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## 2.reading our dataset

# %%
Premier_League_DF = pd.read_csv('H:/Data Science/Python for Data Science/78/12. Data Science Hands-On Projects __ 7.1 2006-2018 EPL stats.csv')

# %%
Premier_League_DF
# Out:
#                      team  wins  losses  goals  total_yel_card  \
# 0       Manchester United  28.0     5.0   83.0            60.0
# 1                 Chelsea  24.0     3.0   64.0            62.0
# 2               Liverpool  20.0    10.0   57.0            44.0
# 3                 Arsenal  19.0     8.0   63.0            59.0
# 4       Tottenham Hotspur  17.0    12.0   57.0            48.0
# ..                    ...   ...     ...    ...             ...
# 235     Huddersfield Town   9.0    19.0   28.0            62.0
# 236          Swansea City   8.0    21.0   28.0            51.0
# 237           Southampton   7.0    16.0   37.0            63.0
# 238            Stoke City   7.0    19.0   35.0            62.0
# 239  West Bromwich Albion   6.0    19.0   31.0            73.0
#
#      total_red_card  total_scoring_att  ontarget_scoring_att  hit_woodwork  \
# 0               1.0              698.0                 256.0          21.0
# ...

# %% [markdown]
# ## 3.find the rows count

# %%
Premier_League_DF.count()
# Out:
# team                    240
# wins                    240
# losses                  240
# goals                   240
# total_yel_card          240
# total_red_card          240
# total_scoring_att       240
# ontarget_scoring_att    240
# hit_woodwork            240
# att_hd_goal             240
# att_pen_goal            240
# att_freekick_goal       240
# att_ibox_goal           240
# att_obox_goal           240
# goal_fastbreak          240
# total_offside           240
# clean_sheet             240
# goals_conceded          240
# saves                   220
# outfielder_block        240
# interception            240
# total_tackle            240
# last_man_tackle         240
# total_clearance         240
# head_clearance          220
# own_goals               240
# penalty_conceded        240
# pen_goals_conceded      240
# total_pass              240
# total_through_ball      220
# total_long_balls        240
# backward_pass           160
# total_cross             240
# ...

# %%
Premier_League_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 42 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   team                  240 non-null    object
#  1   wins                  240 non-null    float64
#  2   losses                240 non-null    float64
#  3   goals                 240 non-null    float64
#  4   total_yel_card        240 non-null    float64
#  5   total_red_card        240 non-null    float64
#  6   total_scoring_att     240 non-null    float64
#  7   ontarget_scoring_att  240 non-null    float64
#  8   hit_woodwork          240 non-null    float64
#  9   att_hd_goal           240 non-null    float64
#  10  att_pen_goal          240 non-null    float64
#  11  att_freekick_goal     240 non-null    float64
#  12  att_ibox_goal         240 non-null    float64
#  13  att_obox_goal         240 non-null    float64
# ...

# %%
print(Premier_League_DF.shape)
# Out:
# (240, 42)

# %% [markdown]
# ## 4.find the most successful season of Manchester United and keep it

# %%
Premier_League_DF.columns
# Out:
# Index(['team', 'wins', 'losses', 'goals', 'total_yel_card', 'total_red_card',
#        'total_scoring_att', 'ontarget_scoring_att', 'hit_woodwork',
#        'att_hd_goal', 'att_pen_goal', 'att_freekick_goal', 'att_ibox_goal',
#        'att_obox_goal', 'goal_fastbreak', 'total_offside', 'clean_sheet',
#        'goals_conceded', 'saves', 'outfielder_block', 'interception',
#        'total_tackle', 'last_man_tackle', 'total_clearance', 'head_clearance',
#        'own_goals', 'penalty_conceded', 'pen_goals_conceded', 'total_pass',
#        'total_through_ball', 'total_long_balls', 'backward_pass',
#        'total_cross', 'corner_taken', 'touches', 'big_chance_missed',
#        'clearance_off_line', 'dispossessed', 'penalty_save',
#        'total_high_claim', 'punches', 'season'],
#       dtype='object')

# %%
teams = Premier_League_DF.groupby('team')

# %%
Manchester_United_info = teams.get_group('Manchester United')
Manchester_United_info
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 0    Manchester United  28.0     5.0   83.0            60.0             1.0
# 20   Manchester United  27.0     5.0   80.0            51.0             2.0
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 61   Manchester United  27.0     7.0   86.0            49.0             4.0
# 80   Manchester United  23.0     4.0   78.0            56.0             3.0
# 101  Manchester United  28.0     5.0   89.0            51.0             1.0
# 120  Manchester United  28.0     5.0   86.0            57.0             1.0
# 146  Manchester United  19.0    12.0   64.0            66.0             3.0
# 163  Manchester United  20.0     8.0   62.0            64.0             5.0
# 183  Manchester United  19.0    10.0   49.0            65.0             1.0
# 205  Manchester United  18.0     5.0   54.0            78.0             2.0
# ...

# %%
Manchester_United_mostwin = Manchester_United_info[Manchester_United_info['wins'] == Manchester_United_info['wins'].max()]
Manchester_United_mostwin
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 0    Manchester United  28.0     5.0   83.0            60.0             1.0
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 101  Manchester United  28.0     5.0   89.0            51.0             1.0
# 120  Manchester United  28.0     5.0   86.0            57.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 0                698.0                 256.0          21.0         12.0  ...
# 40               715.0                 230.0           9.0          7.0  ...
# 101              646.0                 243.0          17.0         16.0  ...
# 120              561.0                 213.0          24.0         14.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 0          918.0         258.0  25686.0                NaN
# 40        1039.0         257.0  30077.0                NaN
# ...

# %%
Manchester_United_most_successfull = Manchester_United_mostwin[Manchester_United_mostwin['losses'] == Manchester_United_mostwin['losses'].min()]
Manchester_United_most_successfull
# Out:
#                  team  wins  losses  goals  total_yel_card  total_red_card  \
# 40  Manchester United  28.0     4.0   68.0            61.0             5.0
#
#     total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 40              715.0                 230.0           9.0          7.0  ...
#
#     total_cross  corner_taken  touches  big_chance_missed  clearance_off_line  \
# 40       1039.0         257.0  30077.0                NaN                 3.0
#
#     dispossessed  penalty_save  total_high_claim  punches     season
# 40         579.0           0.0              56.0     22.0  2008-2009
#
# [1 rows x 42 columns]

# %% [markdown]
# ## 5.find the most successful season of Manchester City and keep it

# %%
Manchester_City_info = teams.get_group('Manchester City')

# %%
Manchester_City_mostwin = Manchester_City_info[Manchester_City_info['wins'] == Manchester_City_info['wins'].max()]
Manchester_City_mostwin
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 220  Manchester City  32.0     2.0  106.0            59.0             2.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 220              665.0                 265.0          23.0         12.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 220        691.0         284.0  35130.0               63.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 220                 4.0         406.0           2.0              21.0
#
#      punches     season
# 220     15.0  2017-2018
#
# [1 rows x 42 columns]

# %%
Manchester_City_most_successfull = Manchester_City_mostwin[Manchester_City_mostwin['losses'] == Manchester_City_mostwin['losses'].min()]
Manchester_City_most_successfull
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 220  Manchester City  32.0     2.0  106.0            59.0             2.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 220              665.0                 265.0          23.0         12.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 220        691.0         284.0  35130.0               63.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 220                 4.0         406.0           2.0              21.0
#
#      punches     season
# 220     15.0  2017-2018
#
# [1 rows x 42 columns]

# %% [markdown]
# ## 6.find the most successful season of Liverpool and keep it

# %%
Liverpool_info = teams.get_group('Liverpool')

# %%
Liverpool_mostwin = Liverpool_info[Liverpool_info['wins'] == Liverpool_info['wins'].max()]
Liverpool_mostwin
# Out:
#           team  wins  losses  goals  total_yel_card  total_red_card  \
# 141  Liverpool  26.0     6.0  101.0            54.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 141              651.0                 258.0          27.0         14.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 141        643.0         224.0  28172.0               64.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 141                 5.0         427.0           1.0              36.0
#
#      punches     season
# 141     29.0  2013-2014
#
# [1 rows x 42 columns]

# %%
Liverpool_most_successfull = Liverpool_mostwin[Liverpool_mostwin['losses'] == Liverpool_mostwin['losses'].min()]
Liverpool_most_successfull
# Out:
#           team  wins  losses  goals  total_yel_card  total_red_card  \
# 141  Liverpool  26.0     6.0  101.0            54.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 141              651.0                 258.0          27.0         14.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 141        643.0         224.0  28172.0               64.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 141                 5.0         427.0           1.0              36.0
#
#      punches     season
# 141     29.0  2013-2014
#
# [1 rows x 42 columns]

# %% [markdown]
# ## 7.find the most successful season of Chelsea and keep it

# %%
Chelsea_info = teams.get_group('Chelsea')

# %%
Chelsea_mostwin = Chelsea_info[Chelsea_info['wins'] == Chelsea_info['wins'].max()]
Chelsea_mostwin
# Out:
#         team  wins  losses  goals  total_yel_card  total_red_card  \
# 200  Chelsea  30.0     5.0   85.0            72.0             0.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 200              580.0                 204.0          17.0          8.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 200        688.0         218.0  27658.0               32.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 200                 3.0         436.0           0.0              38.0
#
#      punches     season
# 200     18.0  2016-2017
#
# [1 rows x 42 columns]

# %%
Chelsea_most_successfull = Chelsea_mostwin[Chelsea_mostwin['losses'] == Chelsea_mostwin['losses'].min()]
Chelsea_most_successfull
# Out:
#         team  wins  losses  goals  total_yel_card  total_red_card  \
# 200  Chelsea  30.0     5.0   85.0            72.0             0.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 200              580.0                 204.0          17.0          8.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 200        688.0         218.0  27658.0               32.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 200                 3.0         436.0           0.0              38.0
#
#      punches     season
# 200     18.0  2016-2017
#
# [1 rows x 42 columns]

# %% [markdown]
# ## 8.find the most successful season of Arsenal and keep it

# %%
Arsenal_info = teams.get_group('Arsenal')

# %%
Arsenal_mostwin = Arsenal_info[Arsenal_info['wins'] == Arsenal_info['wins'].max()]
Arsenal_mostwin
# Out:
#         team  wins  losses  goals  total_yel_card  total_red_card  \
# 22   Arsenal  24.0     3.0   74.0            55.0             3.0
# 143  Arsenal  24.0     7.0   68.0            53.0             4.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 22               627.0                 208.0          13.0         14.0  ...
# 143              523.0                 213.0          15.0         12.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 22         888.0         234.0  28156.0                NaN
# 143        753.0         210.0  29825.0               50.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 22                  2.0         776.0           1.0              45.0
# 143                 3.0         367.0           1.0              70.0
#
#      punches     season
# 22      26.0  2007-2008
# 143     27.0  2013-2014
#
# [2 rows x 42 columns]

# %%
Arsenal_most_successfull = Arsenal_mostwin[Arsenal_mostwin['losses'] == Arsenal_mostwin['losses'].min()]
Arsenal_most_successfull
# Out:
#        team  wins  losses  goals  total_yel_card  total_red_card  \
# 22  Arsenal  24.0     3.0   74.0            55.0             3.0
#
#     total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 22              627.0                 208.0          13.0         14.0  ...
#
#     total_cross  corner_taken  touches  big_chance_missed  clearance_off_line  \
# 22        888.0         234.0  28156.0                NaN                 2.0
#
#     dispossessed  penalty_save  total_high_claim  punches     season
# 22         776.0           1.0              45.0     26.0  2007-2008
#
# [1 rows x 42 columns]

# %% [markdown]
# ## 9.find the most successful season of Tottenham and keep it

# %%
Tottenham_Hotspur_info = teams.get_group('Tottenham Hotspur')

# %%
Tottenham_Hotspur_mostwin = Tottenham_Hotspur_info[Tottenham_Hotspur_info['wins'] == Tottenham_Hotspur_info['wins'].max()]

# %%
Tottenham_Hotspur_most_successfull = Tottenham_Hotspur_mostwin[Tottenham_Hotspur_mostwin['losses'] == Tottenham_Hotspur_mostwin['losses'].min()]
Tottenham_Hotspur_most_successfull
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 201  Tottenham Hotspur  26.0     4.0   86.0            62.0             0.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 201              669.0                 257.0          22.0         10.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 201        761.0         273.0  28150.0               41.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 201                 1.0         484.0           0.0              21.0
#
#      punches     season
# 201     11.0  2016-2017
#
# [1 rows x 42 columns]

# %% [markdown]
# ## 10.create a new dataframe and add these teams

# %%
New_DF = pd.concat([Manchester_United_most_successfull, Manchester_City_most_successfull,
                       Liverpool_most_successfull, Chelsea_most_successfull, 
                       Arsenal_most_successfull, Tottenham_Hotspur_most_successfull])
New_DF
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 220    Manchester City  32.0     2.0  106.0            59.0             2.0
# 141          Liverpool  26.0     6.0  101.0            54.0             1.0
# 200            Chelsea  30.0     5.0   85.0            72.0             0.0
# 22             Arsenal  24.0     3.0   74.0            55.0             3.0
# 201  Tottenham Hotspur  26.0     4.0   86.0            62.0             0.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 40               715.0                 230.0           9.0          7.0  ...
# 220              665.0                 265.0          23.0         12.0  ...
# 141              651.0                 258.0          27.0         14.0  ...
# 200              580.0                 204.0          17.0          8.0  ...
# ...

# %% [markdown]
# ## 11.find the most successful team in the new dataframe

# %%
team_with_mostwin = New_DF[New_DF['wins'] == New_DF['wins'].max()]
team_with_most_successfull = team_with_mostwin[team_with_mostwin['losses'] == team_with_mostwin['losses'].min()]
team_with_most_successfull
# Out:
#                 team  wins  losses  goals  total_yel_card  total_red_card  \
# 220  Manchester City  32.0     2.0  106.0            59.0             2.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 220              665.0                 265.0          23.0         12.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 220        691.0         284.0  35130.0               63.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 220                 4.0         406.0           2.0              21.0
#
#      punches     season
# 220     15.0  2017-2018
#
# [1 rows x 42 columns]

# %%
team_with_mostlosses = New_DF[New_DF['losses'] == New_DF['losses'].max()]
team_with_mostlosses
# Out:
#           team  wins  losses  goals  total_yel_card  total_red_card  \
# 141  Liverpool  26.0     6.0  101.0            54.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 141              651.0                 258.0          27.0         14.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 141        643.0         224.0  28172.0               64.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 141                 5.0         427.0           1.0              36.0
#
#      punches     season
# 141     29.0  2013-2014
#
# [1 rows x 42 columns]

# %% [markdown]
# ## 12.find the team that lost the most in the new dataframe

# %%
team_with_mostlose = New_DF[New_DF['losses'] == New_DF['losses'].max()]
team_with_mostlose
# Out:
#           team  wins  losses  goals  total_yel_card  total_red_card  \
# 141  Liverpool  26.0     6.0  101.0            54.0             1.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 141              651.0                 258.0          27.0         14.0  ...
#
#      total_cross  corner_taken  touches  big_chance_missed  \
# 141        643.0         224.0  28172.0               64.0
#
#      clearance_off_line  dispossessed  penalty_save  total_high_claim  \
# 141                 5.0         427.0           1.0              36.0
#
#      punches     season
# 141     29.0  2013-2014
#
# [1 rows x 42 columns]

# %% [markdown]
# ## 13.find the team with the most accurate shots on target

# %%
Premier_League_DF[Premier_League_DF['ontarget_scoring_att'] == Premier_League_DF['ontarget_scoring_att'].max()]
# Out:
#        team  wins  losses  goals  total_yel_card  total_red_card  \
# 60  Chelsea  27.0     6.0  103.0            54.0             5.0
#
#     total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 60              834.0                 288.0          13.0         16.0  ...
#
#     total_cross  corner_taken  touches  big_chance_missed  clearance_off_line  \
# 60       1083.0         286.0  28914.0                NaN                 3.0
#
#     dispossessed  penalty_save  total_high_claim  punches     season
# 60         503.0           1.0              87.0     30.0  2009-2010
#
# [1 rows x 42 columns]

# %% [markdown]
# ## 14.At new dataframe: Add a new column named “Penalty success rate”, and this column calculates and shows us the team’s penalty success rate

# %%
New_DF_2 = New_DF.copy()

# %%
New_DF_2['Penalty success rate'] =  (New_DF_2['penalty_save']/New_DF_2['penalty_conceded'])*100

# %%
New_DF_2
# Out:
#                   team  wins  losses  goals  total_yel_card  total_red_card  \
# 40   Manchester United  28.0     4.0   68.0            61.0             5.0
# 220    Manchester City  32.0     2.0  106.0            59.0             2.0
# 141          Liverpool  26.0     6.0  101.0            54.0             1.0
# 200            Chelsea  30.0     5.0   85.0            72.0             0.0
# 22             Arsenal  24.0     3.0   74.0            55.0             3.0
# 201  Tottenham Hotspur  26.0     4.0   86.0            62.0             0.0
#
#      total_scoring_att  ontarget_scoring_att  hit_woodwork  att_hd_goal  ...  \
# 40               715.0                 230.0           9.0          7.0  ...
# 220              665.0                 265.0          23.0         12.0  ...
# 141              651.0                 258.0          27.0         14.0  ...
# 200              580.0                 204.0          17.0          8.0  ...
# ...

# %%
New_DF_2['penalty_conceded']
# Out:
# 40     3.0
# 220    2.0
# 141    4.0
# 200    2.0
# 22     4.0
# 201    2.0
# Name: penalty_conceded, dtype: float64

# %%
New_DF_2['pen_goals_conceded']
# Out:
# 40     3.0
# 220    0.0
# 141    3.0
# 200    2.0
# 22     3.0
# 201    2.0
# Name: pen_goals_conceded, dtype: float64

# %% [markdown]
# ## 15.Find the most successful team on penalty saving at new data frame

# %%
New_DF_2[['team','Penalty success rate']][New_DF_2['Penalty success rate'] == New_DF_2['Penalty success rate'].max()]
# Out:
#                 team  Penalty success rate
# 220  Manchester City                 100.0

# %% [markdown]
# ## 16.At new dataframe: Create a bar chart that showed the distribution of teams by points

# %%
teams = Premier_League_DF.groupby('team')
num_groups = teams.ngroups
num_groups
# Out:
# 39

# %%
Figure , Axes = plt.subplots(figsize = (6,6))
plot = Axes.bar(New_DF_2['team'], New_DF_2['wins']*3)
for rect in plot:
    height = rect.get_height()
    Axes.text(rect.get_x() + rect.get_width()/2 , height*1.002 , '%d' %int(height) , ha = 'center' , va = 'bottom')

# %% [markdown]
# ## 17.At new dataframe: Create a pie chart that showed the distribution of teams by goal attempts

# %%
Figure , Axes = plt.subplots(figsize = (10,9))
labels = [New_DF_2['team']]
plot = Axes.pie(New_DF_2['total_scoring_att'], labels =New_DF_2['team'] , autopct = '%1.1f%%' , explode = [0.1,0,0.1,0,0.1,0])
Axes.legend(loc = 'upper right')
